# %% [markdown]
# # Problem Statement

# %% [markdown]
# <html> <font color = Darkblue>
# The purpose is to predict whether the Pima Indian women shows signs of diabetes or not. We are using a dataset collected by "National Institute of Diabetes and Digestive and Kidney Diseases" which consists of a number of attributes which would help us to perform this prediction.
# </font>
# </html>

# %% [markdown]
# <html>
# <font color = blue>
# <b>Constraints on data collection </b>
#
# </font>
# </html>

# %% [markdown]
# <html> <font color = Darkblue>
# All patients whose data has been collected are females at least 21 years old of Pima Indian heritage
# </font>
# </html>

# %%
#Import all the necessary modules
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Q1. Load the PIMA Indian Diabetes file into Python DataFrame.

# %% [markdown]
# The file can be accessed directly from the URL (https://archive.ics.uci.edu/ml/machine-learning-databases/pima-indians-diabetes/pima-indians-diabetes.data or you may first download it to a local folder and then load it into Python dataframe.  Let us assume the data frame is named pima_df

# %%
# Importing Data file
colnames = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
df = pd.read_csv("pima-indians-diabetes-1.data", names= colnames)
df.head(5)
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %% [markdown]
# It is always a good practice to eye-ball raw data to get a feel of the data in terms of number of structure of the file, number of attributes, types of attributes and a general idea of likely challenges in the dataset. You would notice that it is a comma separated file. There are no column names!. Check the associated folders and find out about each attribute the name. What information is available about the data.

# %% [markdown]
# # Q2. Print 10 samples from the dataset

# %%
df.head(10)
# Out:
#    preg  plas  pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1
# 5     5   116    74     0     0  25.6  0.201   30      0
# 6     3    78    50    32    88  31.0  0.248   26      1
# 7    10   115     0     0     0  35.3  0.134   29      0
# 8     2   197    70    45   543  30.5  0.158   53      1
# 9     8   125    96     0     0   0.0  0.232   54      1

# %% [markdown]
# # Q3 Print the datatypes of each column and the shape of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# preg     768 non-null int64
# plas     768 non-null int64
# pres     768 non-null int64
# skin     768 non-null int64
# test     768 non-null int64
# mass     768 non-null float64
# pedi     768 non-null float64
# age      768 non-null int64
# class    768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.0 KB

# %% [markdown]
# There are '0's in the data. Are they really valid '0's or they are missing values?
# Plasma, BP, skin thickness etc. these values cannot be 0.
# look at column by column logically to understand this.

# %% [markdown]
# # Q4 Replace all the 0s in the column with the median of the same column value accordingly.

# %%
df['preg']=df['preg'].replace(0,df['preg'].median())
df['plas']=df['plas'].replace(0,df['plas'].median())
df['pres']=df['pres'].replace(0,df['pres'].median())
df['skin']=df['skin'].replace(0,df['skin'].median())
df['test']=df['test'].replace(0,df['test'].median())
df['mass']=df['mass'].replace(0,df['mass'].median())
df
# Out:
#      preg  plas  pres  skin   test  mass   pedi  age  class
# 0       6   148    72    35   30.5  33.6  0.627   50      1
# 1       1    85    66    29   30.5  26.6  0.351   31      0
# 2       8   183    64    23   30.5  23.3  0.672   32      1
# 3       1    89    66    23   94.0  28.1  0.167   21      0
# 4       3   137    40    35  168.0  43.1  2.288   33      1
# 5       5   116    74    23   30.5  25.6  0.201   30      0
# 6       3    78    50    32   88.0  31.0  0.248   26      1
# 7      10   115    72    23   30.5  35.3  0.134   29      0
# 8       2   197    70    45  543.0  30.5  0.158   53      1
# 9       8   125    96    23   30.5  32.0  0.232   54      1
# 10      4   110    92    23   30.5  37.6  0.191   30      0
# 11     10   168    74    23   30.5  38.0  0.537   34      1
# 12     10   139    80    23   30.5  27.1  1.441   57      0
# 13      1   189    60    23  846.0  30.1  0.398   59      1
# 14      5   166    72    19  175.0  25.8  0.587   51      1
# 15      7   100    72    23   30.5  30.0  0.484   32      1
# 16      3   118    84    47  230.0  45.8  0.551   31      1
# 17      7   107    74    23   30.5  29.6  0.254   31      1
# 18      1   103    30    38   83.0  43.3  0.183   33      0
# 19      1   115    70    30   96.0  34.6  0.529   32      1
# 20      3   126    88    41  235.0  39.3  0.704   27      0
# 21      8    99    84    23   30.5  35.4  0.388   50      0
# 22      7   196    90    23   30.5  39.8  0.451   41      1
# 23      9   119    80    35   30.5  29.0  0.263   29      1
# 24     11   143    94    33  146.0  36.6  0.254   51      1
# 25     10   125    70    26  115.0  31.1  0.205   41      1
# 26      7   147    76    23   30.5  39.4  0.257   43      1
# 27      1    97    66    15  140.0  23.2  0.487   22      0
# 28     13   145    82    19  110.0  22.2  0.245   57      0
# 29      5   117    92    23   30.5  34.1  0.337   38      0
# ..    ...   ...   ...   ...    ...   ...    ...  ...    ...
# 738     2    99    60    17  160.0  36.6  0.453   21      0
# 739     1   102    74    23   30.5  39.5  0.293   42      1
# 740    11   120    80    37  150.0  42.3  0.785   48      1
# 741     3   102    44    20   94.0  30.8  0.400   26      0
# 742     1   109    58    18  116.0  28.5  0.219   22      0
# 743     9   140    94    23   30.5  32.7  0.734   45      1
# 744    13   153    88    37  140.0  40.6  1.174   39      0
# 745    12   100    84    33  105.0  30.0  0.488   46      0
# 746     1   147    94    41   30.5  49.3  0.358   27      1
# 747     1    81    74    41   57.0  46.3  1.096   32      0
# 748     3   187    70    22  200.0  36.4  0.408   36      1
# 749     6   162    62    23   30.5  24.3  0.178   50      1
# 750     4   136    70    23   30.5  31.2  1.182   22      1
# 751     1   121    78    39   74.0  39.0  0.261   28      0
# 752     3   108    62    24   30.5  26.0  0.223   25      0
# 753     3   181    88    44  510.0  43.3  0.222   26      1
# 754     8   154    78    32   30.5  32.4  0.443   45      1
# 755     1   128    88    39  110.0  36.5  1.057   37      1
# 756     7   137    90    41   30.5  32.0  0.391   39      0
# 757     3   123    72    23   30.5  36.3  0.258   52      1
# 758     1   106    76    23   30.5  37.5  0.197   26      0
# 759     6   190    92    23   30.5  35.5  0.278   66      1
# 760     2    88    58    26   16.0  28.4  0.766   22      0
# 761     9   170    74    31   30.5  44.0  0.403   43      1
# 762     9    89    62    23   30.5  22.5  0.142   33      0
# 763    10   101    76    48  180.0  32.9  0.171   63      0
# 764     2   122    70    27   30.5  36.8  0.340   27      0
# 765     5   121    72    23  112.0  26.2  0.245   30      0
# 766     1   126    60    23   30.5  30.1  0.349   47      1
# 767     1    93    70    31   30.5  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# # Q5 Print the descriptive statistics of each & every column using describe() function

# %%
df.describe()
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     4.278646  121.656250   72.386719   27.334635   94.652344   32.450911
# std      3.021516   30.438286   12.096642    9.229014  105.547598    6.875366
# min      1.000000   44.000000   24.000000    7.000000   14.000000   18.200000
# 25%      2.000000   99.750000   64.000000   23.000000   30.500000   27.500000
# 50%      3.000000  117.000000   72.000000   23.000000   31.250000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %% [markdown]
# # Q6 See the distribution of 'Class' variable and plot it using appropriate graph.

# %%
df.hist(figsize=(20, 20), bins=80, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0xa7cbd16c>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa9b275ac>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa9b20d0c>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0xa789eeac>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa7bbbf4c>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa7bbbc4c>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0xa7b68acc>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa7c02e0c>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0xa78dbf8c>]],
#       dtype=object)

# %% [markdown]
# #Just for your understanding - Using univariate analysis check the individual attributes for their basic statistic such as central values, spread, tails etc. What are your observations (any two attributes). Its an optional step and will not be graded.

# %%
df.kurtosis(numeric_only  = True)
# Out:
# preg     0.744680
# plas    -0.257847
# pres     1.098239
# skin     4.716995
# test     9.741075
# mass     0.921296
# pedi     5.594954
# age      0.643159
# class   -1.600930
# dtype: float64

# %%
df.skew(numeric_only  = True)
# Out:
# preg     1.111795
# plas     0.535587
# pres     0.141885
# skin     1.223057
# test     2.693181
# mass     0.601059
# pedi     1.919911
# age      1.129597
# class    0.635017
# dtype: float64

# %% [markdown]
# # Q7. Use pairplots and correlation method to observe the relationship between different variables and state your insights.
# Hint: Use seaborn plot and check the relationship between different variables

# %%
import seaborn as sns
sns.pairplot(df , diag_kind='kde')

# %%
df.corr()
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.149326  0.247530  0.060706 -0.059580  0.080540 -0.016151
# plas   0.149326  1.000000  0.218937  0.172143  0.357573  0.231400  0.137327
# pres   0.247530  0.218937  1.000000  0.147809 -0.028721  0.281132 -0.002378
# skin   0.060706  0.172143  0.147809  1.000000  0.238188  0.546951  0.142977
# test  -0.059580  0.357573 -0.028721  0.238188  1.000000  0.189022  0.178029
# mass   0.080540  0.231400  0.281132  0.546951  0.189022  1.000000  0.153506
# pedi  -0.016151  0.137327 -0.002378  0.142977  0.178029  0.153506  1.000000
# age    0.538169  0.266909  0.324915  0.054514 -0.015413  0.025744  0.033561
# class  0.245466  0.492782  0.165723  0.189065  0.148457  0.312249  0.173844
#
#             age     class
# preg   0.538169  0.245466
# plas   0.266909  0.492782
# pres   0.324915  0.165723
# skin   0.054514  0.189065
# test  -0.015413  0.148457
# mass   0.025744  0.312249
# pedi   0.033561  0.173844
# age    1.000000  0.238356
# class  0.238356  1.000000

# %% [markdown]
# Using the plot - infer the relationship between different variables

# %% [markdown]
# # Q8 Split the pima_df into training and test set in the ratio of 70:30 (Training:Test).</b>

# %%
### SPLITTING INTO TRAINING AND TEST SETS
from sklearn.model_selection import train_test_split
X = df.drop('class', axis=1)
Y = df[['class']]

test_size = 0.30 # taking 70:30 training and test set
seed = 1  # Random numbmer seeding for reapeatability of the code
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)
print(X_train.shape)
print(X_test.shape)
# Out:
# (537, 8)
# (231, 8)

# %% [markdown]
# # Q9 Create the decision tree model using “entropy” method of reducing the entropy and fit it to training data.</b>

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(criterion = 'entropy' )
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# # Q10 Print the accuracy of the model & print the confusion matrix

# %%
dt_model.score(X_train , y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
y_predict = dt_model.predict(X_test)
print("Confusion Matrix:\n",confusion_matrix(y_predict,y_test))
# Out:
# Confusion Matrix:
#  [[112  32]
#  [ 34  53]]

# %% [markdown]
# Print the feature importance of the decision model - Optional

# %%
train_char_label = ['No', 'Yes']
print (pd.DataFrame(dt_model.feature_importances_, columns = ["Imp"], index = X_train.columns))
# Out:
#            Imp
# preg  0.066457
# plas  0.230531
# pres  0.139895
# skin  0.049595
# test  0.012805
# mass  0.245937
# pedi  0.119719
# age   0.135062

# %% [markdown]
# # Q12 Apply the Random forest model and print the accuracy of Random forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
rfcl = RandomForestClassifier(n_estimators = 50)
rfcl = rfcl.fit(X_train, y_train)
# Out:
# /home/stumble/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dt_model.score(X_test , y_test)
# Out:
# 0.7142857142857143

# %%
y_predict = rfcl.predict(X_test)
print(confusion_matrix(y_predict,y_test))
# Out:
# [[128  33]
#  [ 18  52]]

# %% [markdown]
# # Q13 Apply Adaboost Ensemble Algorithm for the same data and print the accuracy.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn import metrics
abcl = AdaBoostClassifier(base_estimator=dt_model, n_estimators=10)
abcl = abcl.fit(X_train, y_train)
# Out:
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_predict = abcl.predict(X_test)
print(abcl.score(X_test , y_test))
print(metrics.confusion_matrix(y_test, y_predict))
# Out:
# 0.7186147186147186
# [[111  35]
#  [ 30  55]]

# %% [markdown]
# # Q14 - Apply Bagging Classifier Algorithm and print the accuracy.

# %%
from sklearn.ensemble import BaggingClassifier
bgcl = BaggingClassifier(base_estimator=dt_model, n_estimators=50)
bgcl = bgcl.fit(X_train, y_train)
y_predict = bgcl.predict(X_test)

print(bgcl.score(X_test , y_test))
print(metrics.confusion_matrix(y_test, y_predict))
# Out:
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8008658008658008
# [[129  17]
#  [ 29  56]]

# %% [markdown]
# # Q15 - Apply GradientBoost Classifier Algorithm for the same data and print the accuracy

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 50)
gbcl2 = gbcl.fit(X_train, y_train)
# Out:
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_predict = gbcl2.predict(X_test)
print(gbcl2.score(X_test , y_test))
print(metrics.confusion_matrix(y_test, y_predict))
# Out:
# 0.7965367965367965
# [[126  20]
#  [ 27  58]]

# %% [markdown]
# # Next steps are optional and will not be graded.

# %% [markdown]
# Voting is one of the simplest ways of combining the predictions from multiple machine learning algorithms.
#
# It works by first creating two or more standalone models from your training dataset. A Voting Classifier can then be used to wrap your models and average the predictions of the sub-models when asked to make predictions for new data.

# %% [markdown]
# Apply Voting Classfier on the given dataset and state your insights.

# %%
from sklearn import model_selection
from sklearn import ensemble
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB 
from sklearn.ensemble import VotingClassifier

rf_est = ensemble.RandomForestClassifier(n_estimators = 750, criterion = 'gini', max_features = 'sqrt', max_depth = 3, min_samples_split = 4, min_samples_leaf = 2, n_jobs = 50, random_state = 42, verbose = 1)
gbm_est = ensemble.GradientBoostingClassifier(n_estimators = 900, learning_rate = 0.0008, loss = 'exponential', min_samples_split = 3, min_samples_leaf = 2, max_features ='sqrt', max_depth = 3,  random_state = 42, verbose = 1)
et_est = ensemble.ExtraTreesClassifier(n_estimators = 750, max_features = 'sqrt', max_depth = 35,  n_jobs = 50, criterion = 'entropy', random_state = 42, verbose = 1)

voting_est = ensemble.VotingClassifier(estimators = [('rf', rf_est),('gbm', gbm_est),('et', et_est)],
                                       voting = 'soft', weights = [3,5,2],
                                       n_jobs = 50)
                                       
voting_est.fit(X_train, y_train)
print("VotingClassifier Score: " + str(voting_est.score(X_train, y_train)))
print("VotingClassifier Estimators: " + str(voting_est.estimators_))
# Out:
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:95: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#       Iter       Train Loss   Remaining Time
#          1           0.9478           36.29m
#          2           0.9476           18.88m
#          3           0.9474           13.11m
#          4           0.9471           10.06m
#          5           0.9470            8.28m
#          6           0.9468            7.09m
#          7           0.9466            6.61m
#          8           0.9465            6.83m
#          9           0.9463            6.58m
#         10           0.9461            6.52m
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    2.4s
#         20           0.9442            4.22m
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    3.9s
#         30           0.9424            3.29m
#         40           0.9405            2.92m
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    5.5s
#         50           0.9387            2.67m
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    6.7s finished
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    7.8s finished
#         60           0.9369            2.43m
#         70           0.9351            2.13m
#         80           0.9334            1.86m
#         90           0.9317            1.63m
#        100           0.9298            1.48m
#        200           0.9127           41.69s
#        300           0.8966           27.51s
#        400           0.8812           18.26s
#        500           0.8666           12.85s
#        600           0.8530            8.25s
#        700           0.8401            4.85s
#        800           0.8282            2.19s
#        900           0.8166            0.00s
# [Parallel(n_jobs=50)]: Done  11 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    1.6s finished
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    0.7s
# VotingClassifier Score: 0.9143389199255121
# VotingClassifier Estimators: [RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=2, min_samples_split=4,
#             min_weight_fraction_leaf=0.0, n_estimators=750, n_jobs=50,
#             oob_score=False, random_state=42, verbose=1, warm_start=False), GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.0008, loss='exponential', max_depth=3,
#               max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=2, min_samples_split=3,
#               min_weight_fraction_leaf=0.0, n_estimators=900,
#               presort='auto', random_state=42, subsample=1.0, verbose=1,
#               warm_start=False), ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
#            max_depth=35, max_features='sqrt', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=750, n_jobs=50,
#            oob_score=False, random_state=42, verbose=1, warm_start=False)]
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    1.5s finished
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
y_predict = voting_est.predict(X_test)
print(voting_est.score(X_test , y_test))
print(metrics.confusion_matrix(y_test, y_predict))
# Out:
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    1.6s finished
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    0.5s finished
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    1.3s finished
# [Parallel(n_jobs=50)]: Done 100 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=50)]: Done 350 tasks      | elapsed:    0.7s
# 0.7662337662337663
# [[136  10]
#  [ 44  41]]
# [Parallel(n_jobs=50)]: Done 750 out of 750 | elapsed:    1.0s finished
# /home/stumble/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
